# %% [markdown]
# # FIT1061 Learning Plan
#
# **Name:** pinyo Chen
# **Student ID:**  37524720
# **Date:**july 28, 2026

# %% [markdown]
# ## My background
#
# *What programming experience do you have? Which languages have you used? How comfortable are you with Python specifically? Be honest: this helps your tutor support you.*
#
# Write your response here.
#
# I've used c, c++, java, and python before, but it will still need a lot of practice to be fluent. I don't have much experience with python implementation, but i can understand it pretty well, so I guess I could pick up after a few attempts.

# %% [markdown]
# ## My OnTrack experience
#
# *Have you completed a class that used OnTrack before? If so, what did you learn from the experience? If not, write that this is your first time using OnTrack.*
#
# Write your response here.
#
# I haven't used OnTrack at all, and because I am a international student, I am still a bit confused about the teaching environment.

# %% [markdown]
# ## What excites me about AI
#
# *What drew you to this unit? Is there a topic, application, or question about AI that you're curious about? There are no wrong answers.*
#
# Write your response here.
#
#
# I am pretty interested in how AI learns, especially with different tools it uses that end up having a very different outcome. I am also curious about where else it can be implemented.

# %% [markdown]
# ## My target grade
#
# *Which grade are you aiming for? (See the grade descriptors in the task spec.) Why did you choose this target? What will you need to do to achieve it?*
#
# **Target grade:** _______above 80________
#
# Write your response here.
#
# I will try to match up all the requirements and learn as much as i can, and i also need this grade for further study.

# %% [markdown]
# ## Acknowledgement
#
# I have read and understood:
# - [X] The FIT1061 assessment structure (portfolio-based, cumulative grades)
# - [X] The feedback and resubmission process
# - [X] The competency hurdle tests (Test 1 ~W5/6, Test 2 ~W9/10)
# - [X] The academic integrity requirements, including the AI use policy
#
# **Signature (type your name):** pinyo Chen
# **Date:** July 28, 2026
