# %% [markdown]
# # P1.1 — Hello AI
#
# **FIT1061 Introduction to Artificial Intelligence**
#
# This notebook checks that your Python and Jupyter environment is set up correctly. Run every cell from top to bottom. If all cells complete without errors, you're ready for the semester.
#
# **Instructions:** Click into each cell and press `Shift+Enter` to run it. Read the output and fix any issues before moving on.

# %% [markdown]
# ## Step 1: Python is running
#
# Run the cell below. If you see `Hello, AI!` printed, Python is working inside Jupyter.

# %%
print("Hello, AI!")
# Out:
# Hello, AI!

# %% [markdown]
# ## Step 2: Python version check
#
# FIT1061 requires Python 3.9 or later. Run the cell below to check your version.

# %%
import sys

version = sys.version_info
print(f"Python version: {version.major}.{version.minor}.{version.micro}")

if version >= (3, 9):
    print("OK: Python 3.9+ detected.")
else:
    print("WARNING: You need Python 3.9 or later. Please update your installation.")
# Out:
# Python version: 3.12.13
# OK: Python 3.9+ detected.

# %% [markdown]
# ## Step 3: NumPy
#
# NumPy is the library we'll use for array computation from Week 6 onwards. Run the cell below to check it's installed and working.

# %%
import numpy as np

print(f"NumPy version: {np.__version__}")

# Quick test: create a small array and compute its mean
test_array = np.array([1, 2, 3, 4, 5])
print(f"Test array: {test_array}")
print(f"Mean: {test_array.mean()}")
print("OK: NumPy is working.")
# Out:
# NumPy version: 2.5.1
# Test array: [1 2 3 4 5]
# Mean: 3.0
# OK: NumPy is working.

# %% [markdown]
# ## Step 4: Matplotlib
#
# Matplotlib is the plotting library we'll use to visualise results. Run the cell below to check it works and that plots display inline in your notebook.

# %%
import matplotlib.pyplot as plt

print(f"Matplotlib version: {plt.matplotlib.__version__}")

# Quick test: plot a simple line
x = [0, 1, 2, 3, 4]
y = [0, 1, 4, 9, 16]

plt.figure(figsize=(5, 3))
plt.plot(x, y, marker='o')
plt.title("Setup check: y = x²")
plt.xlabel("x")
plt.ylabel("y")
plt.tight_layout()
plt.show()

print("OK: Matplotlib is working. You should see a plot above.")
# Out:
# Matplotlib version: 3.11.1
# OK: Matplotlib is working. You should see a plot above.

# %% [markdown]
# ## Step 5: All checks passed
#
# Run the final cell to confirm everything is working.

# %%
print("="*50)
print("ALL CHECKS PASSED")
print("="*50)
print()
print("Your environment is ready for FIT1061.")
# Out:
# ...
# ALL CHECKS PASSED
# ...
#
# Your environment is ready for FIT1061.
